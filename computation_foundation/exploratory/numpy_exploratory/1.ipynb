# %% [markdown]
# ### 10:00:00/ 7:35-8:35

# %% [markdown]
# 1. How about the project with Gaussian elimination and coding and attaching a plot of every step, of how does a particular step changes the plane, and how do changes in matrix affect the plot?
#
# 2. https://youtu.be/bnC848ie16Q?si=JKd-dx4Oy4r1Y2z1

# %% [markdown]
# ### maybe more question like these
#
# 1. 9. **How do you detect where a function changes behavior and split the array accordingly?**
#    Example: one formula before the breakpoint, another after it.
#    This is more algorithmic than algebraic.

# %% [markdown]
# ---

# %%
"""2. **How do you handle a function with a restricted domain 
    and still keep the original array shape?**
   Example: (f(x)=\sqrt{x-3})."""

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-20,20,100)

y = np.full_like(x, np.nan)

mask = x >= 3

y[mask] = np.sqrt(x[mask] - 3)

plt.plot(x,y)
plt.grid()
plt.show()

np.zer

# %%
"""How do you build a clean pipeline where output from one function becomes input to another, but only after validation?
Example: compute g(x)=log(x+2), then feed that into h(u)=u
2
+1.
Some values will fail early. You need to decide what gets passed forward."""

x = np.linspace()
