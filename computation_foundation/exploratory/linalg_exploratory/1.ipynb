# %% [markdown]
# Based on the image provided, here is the extracted text:
#
# Shade in the pyramid of combinations $cu + dv + ew$ with $c \geq 0, d \geq 0, e \geq 0$ and $c + d + e \leq 1$. Mark the vector $\frac{1}{2}(u + v + w)$ as inside or outside this pyramid.
