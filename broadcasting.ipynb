# %%
import numpy as np
import pandas as pd

x = np.arange(10).reshape(2,5)

print(x, x.shape)

# %%
y = np.arange(400).reshape(2,5,40)

print(y, y.shape)

# %% [markdown]
# -------

# %%
a = np.random.rand(10,3)
a
# Out:
# array([[0.8170616 , 0.80049689, 0.96633506],
#        [0.2238549 , 0.20654243, 0.71636937],
#        [0.37103652, 0.93627608, 0.53253432],
#        [0.0888203 , 0.37195229, 0.71268121],
#        [0.91294565, 0.04674875, 0.20846444],
#        [0.45468459, 0.53838136, 0.67909099],
#        [0.33854882, 0.58178548, 0.56963917],
#        [0.69315018, 0.6505944 , 0.19469902],
#        [0.3919133 , 0.76372154, 0.94660595],
#        [0.78577656, 0.83698454, 0.71761462]])

# %%
b = np.array([1,2,3])

a*b
# Out:
# array([[0.8170616 , 1.60099379, 2.89900517],
#        [0.2238549 , 0.41308486, 2.14910812],
#        [0.37103652, 1.87255216, 1.59760295],
#        [0.0888203 , 0.74390459, 2.13804364],
#        [0.91294565, 0.09349749, 0.62539331],
#        [0.45468459, 1.07676272, 2.03727297],
#        [0.33854882, 1.16357096, 1.70891751],
#        [0.69315018, 1.3011888 , 0.58409705],
#        [0.3919133 , 1.52744307, 2.83981786],
#        [0.78577656, 1.67396909, 2.15284387]])

# %%
import numpy as np

line = np.arange(1, 11) * 2000

print(line)
# Out:
# [ 2000  4000  6000  8000 10000 12000 14000 16000 18000 20000]

# %%
import numpy as np
import matplotlib.pyplot as plt

line = np.arange(1, 11) * 2000

plt.plot(line)
plt.show()
