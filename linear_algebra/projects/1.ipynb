# %% [markdown]
# ### 1:15
# 1. Intertwine proofs with code

# %% [markdown]
# # Ideas
#
# 1. can you come up with a algorithm to check span range.

# %%
import numpy as np
from vector_independence import vector_independence
x = np.array([[1],
            [2]])
y = np.array([[5],
            [2]])

matrix = vector_independence(x,y)
# Out:
# Independent

# %%
from matrix_transform_2d import matrix_transform_2d
from matrix_transform_2d import matrix_transform_2dplus

vector = np.array([[1],
                    [1]])

matrix_transform_2d(vector, matrix)

# %%
matrix_transform_2dplus(vector, matrix)

# %% [markdown]
# -----

# %%
from visualize_lin_combination import visualize_linear_combination


vector = np.array([[1],
                    [1]])
visualize_linear_combination(vector, matrix)
