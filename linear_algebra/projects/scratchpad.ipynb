# %% [markdown]
# ### Intertwine proofs with code
#
# ### 11:45-1:05

# %% [markdown]
# # Ideas
#
# 1. make a function that individually first states and then visualizes how each matrice row changes the vector, algebrically and graphically.
# 2. can you come up with a algorithm to check span range

# %%
import numpy as np
import matplotlib.pyplot as plt
from matrix_transform_2d import matrix_transform_2d
from vector_independence import vector_independence

x = np.array([[1],
            [2]])
x1 = np.array([[5],
            [2]])

vector_independence(x,x1)
# Out:
# Independent: -7.999999999999998
# array([[1, 5],
#        [2, 2]])

# %%
matrix = vector_independence(x,x1)
vector = np.array([[1],
                [2]])

matrix_transform_2d(vector, matrix)
# Out:
# Independent: -7.999999999999998
