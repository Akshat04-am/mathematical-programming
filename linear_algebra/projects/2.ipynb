# %% [markdown]
# # 1:40
# # 1:10
# # 00
# # 7:40

# %% [markdown]
# plot all the shapes

# %%
import numpy as np
from visualize_lin_combination import visualize_linear_combination
mat1 = np.array([[-1],
                 [0]])
mat2= np.array([[0],
                [1]])

matrix = np.column_stack((mat1, mat2))

vector = np.array([[5],
                   [5]])

visualize_linear_combination(vector, matrix)

# %%
import numpy as np
import matplotlib.pyplot as plt

from visualize_lin_combination import example

example()
# Out:
# Matrix:
#  [[1 3]
#  [2 2]]
# Determinant: -4.0
