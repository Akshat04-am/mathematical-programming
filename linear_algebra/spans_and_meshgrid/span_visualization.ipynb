# %%
# visualizing span by explicitly defined scalars.
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')

# two independent unit vectors.
vec_1 = np.array([1,0])
vec_2 = np.array([0,1])

# explicitly defined scalar range.
scalar_limits = [1,20]
scalars = np.arange(scalar_limits[0], 
                    scalar_limits[1])

# %%
# A grid of 3 vectors
vectors = np.array([
    [1, 2],
    [3, 5],
    [4, 1]
])

# Plot all x-coords and all y-coords easily
plt.scatter(vectors[:, 0], vectors[:, 1])
# Out:
# (1, 3)
# 2

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 1. Dummy data
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))


surf = ax.plot_surface(X, Y, Z, cmap='viridis')
plt.show()
