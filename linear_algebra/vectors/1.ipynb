# %% [markdown]
# ### 10:00:00/ 5:45

# %% [markdown]
# ## stress test Cauchy-Schwarz inequality and triangle theorem

# %% [markdown]
# ---

# %% [markdown]
# ## build a tool to input vectors and how many times you want it dynamically

# %% [markdown]
# ## can you come up with a algorithm to check span range
