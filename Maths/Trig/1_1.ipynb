# %%
import numpy as np

angle = 45

x = np.cos(angle)
print(x)
# Out:
# 0.5253219888177297

# %%
# Method 1: Using np.radians() (Recommended)
import numpy as np

angle_rad = np.radians(45)

x = np.cos(angle_rad)
print(x)
# Out:
# 0.7071067811865476
