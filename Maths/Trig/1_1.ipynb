# %% [markdown]
# # Start- 8:45to 9:50

# %%
import numpy as np

degrees = np.arange(0, 361, 15)

print(f"{'Degrees':<10} | {'Func':<5} | {'Value':<10}")
print("-"*30)

for i,deg in enumerate(degrees):
    rad = np.radians(deg)
# Out:
# Degrees    | Func  | Value
# ------------------------------
# 0          | sin   | 0.0000
# 15         | cos   | 0.9659
# 30         | sin   | 0.5000
# 45         | cos   | 0.7071
# 60         | sin   | 0.8660
# 75         | cos   | 0.2588
# 90         | sin   | 1.0000
# 105        | cos   | -0.2588
# 120        | sin   | 0.8660
# 135        | cos   | -0.7071
# 150        | sin   | 0.5000
# 165        | cos   | -0.9659
# 180        | sin   | 0.0000
# 195        | cos   | -0.9659
# 210        | sin   | -0.5000
# 225        | cos   | -0.7071
# 240        | sin   | -0.8660
# 255        | cos   | -0.2588
# 270        | sin   | -1.0000
# 285        | cos   | 0.2588
# 300        | sin   | -0.8660
# 315        | cos   | 0.7071
# 330        | sin   | -0.5000
# 345        | cos   | 0.9659
# 360        | sin   | -0.0000
